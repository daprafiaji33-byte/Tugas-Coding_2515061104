# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x = 104

# %%
#tampilkan tipe data dari x
type (x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y = 40

# %%
#tampilkan tipe data dari y
type (y)
# Out:
# int

# %%
#jumlahkan x dan y
x + y
# Out:
# 144

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
z_float = 1.4

# %%
#jumlahkan x_float dengan y
z_float + y
# Out:
# 41.4

# %%
#tampilkan tipe data dari x_float
type (z_float)
# Out:
# float

# %% [markdown]
# Tensor flow

# %%
import tensorflow as tf

# %%
#buat variable x
x_tf = tf.Variable(410, dtype=tf.int16)

# %%
#tampilkan tipe data dari x
x_tf.dtype
# Out:
# tf.int16

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_tf = tf.Variable(4, dtype=tf.int16)

# %%
#tampilkan tipe data dari y
y_tf.dtype
# Out:
# tf.int16

# %%
#tambahkan x+y
jumlah = tf.add(x_tf, y_tf)
jumlah
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=414>
