# %%
#selesaikan soal berikut
# what is the transpose of this vector?
'''vector = ([25], [2], [-3], [-23])'''

# %%
import numpy as np

# %%
v = np.array([[25], [2], [-3], [-23]])

# %%
# Melakukan transpose
v_transpose = v.T
v_transpose
# Out:
# array([[ 25,   2,  -3, -23]])
